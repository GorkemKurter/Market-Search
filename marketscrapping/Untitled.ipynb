# %%
# !pip install scrapy
# Out:
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python -m pip install --upgrade pip

# %%
# !scrapy shell https://pricespy.co.uk/c/washing-machines?1247=2342
# Out:
# 2023-12-26 05:54:26 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: marketscrapping)
# 2023-12-26 05:54:26 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.10.13 (main, Dec  8 2023, 04:58:09) [GCC 9.4.0], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.7, Platform Linux-6.2.0-1018-azure-x86_64-with-glibc2.31
# 2023-12-26 05:54:26 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-12-26 05:54:26 [asyncio] DEBUG: Using selector: EpollSelector
# 2023-12-26 05:54:26 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2023-12-26 05:54:26 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2023-12-26 05:54:26 [scrapy.extensions.telnet] INFO: Telnet Password: 9ec59b3560648385
# 2023-12-26 05:54:26 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
# ...
